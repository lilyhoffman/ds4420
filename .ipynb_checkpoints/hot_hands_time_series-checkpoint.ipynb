# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score, log_loss, accuracy_score
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %% [markdown]
# # Hot Hand Analysis
#
# Goal: Test whether previous shot outcomes affect the probability of making the next shot.
#
# Approach:
# - Treat shot outcomes as a time series
# - Use autocorrelation (ACF)
# - Fit a logistic autoregressive model

# %%
# Load data
pbp_2023 = pd.read_csv("pbp/pbp2023.csv")

# Filter to S. Curry's shot attempts
df = pbp_2023[pbp_2023["playerid"] == 201939].copy()
df = df[df["type"].isin(["Made Shot", "Missed Shot"])].copy()

# Basic summary
print("Shape:", df.shape)
print("Rows after filters:", len(df))
print("Unique games:", df["gameid"].nunique())

print("\nShots per game:")
print(df["gameid"].value_counts().head())
pbp_2023
# Out:
# Shape: (1444, 16)
# Rows after filters: 1444
# Unique games: 69
#
# Shots per game:
# gameid
# 42200167    38
# 42200234    30
# 42200236    28
# 22200660    28
# 22201041    28
# Name: count, dtype: int64
#           gameid  period        clock  h_pts  a_pts team    playerid  \
# 0       22200001       1  PT12M00.00S    0.0    0.0  NaN           0
# 1       22200001       1  PT12M00.00S    NaN    NaN  BOS      201143
# 2       22200001       1  PT11M38.00S    NaN    NaN  PHI      203954
# 3       22200001       1  PT11M38.00S    NaN    NaN  BOS     1627759
# 4       22200001       1  PT11M35.00S    NaN    NaN  PHI      200782
# ...          ...     ...          ...    ...    ...  ...         ...
# 646362  52200211       4  PT00M50.80S    NaN    NaN  MIN     1629162
# 646363  52200211       4  PT00M47.50S    NaN    NaN  MIN     1630233
# 646364  52200211       4  PT00M37.70S  120.0   95.0  OKC     1631172
# 646365  52200211       4  PT00M13.60S    NaN    NaN  NaN  1610612750
# 646366  52200211       4  PT00M00.00S  120.0   95.0  NaN           0
#
#                player         type                   subtype  result    x   y  \
# 0                 NaN       period                     start     NaN    0   0
# 1          A. Horford    Jump Ball                       NaN     NaN    0   0
# 2           J. Embiid  Missed Shot  Turnaround Fadeaway shot  Missed -118  50
# 3            J. Brown          NaN                       NaN     NaN    0   0
# 4           P. Tucker      Rebound                   Unknown     NaN    0   0
# ...               ...          ...                       ...     ...  ...  ..
# 646362  J. McLaughlin          NaN                       NaN     NaN    0   0
# 646363      N. Knight     Turnover                 Traveling     NaN    0   0
# 646364       O. Dieng    Made Shot        Driving Layup Shot    Made    6  13
# 646365            NaN     Turnover       Shot Clock Turnover     NaN    0   0
# 646366            NaN       period                       end     NaN    0   0
#
#         dist                                         desc  season
# 0          0            Start of 1st Period (7:36 PM EST)    2023
# 1          0  Jump Ball Horford vs. Embiid: Tip to Harris    2023
# 2         13     MISS Embiid 13' Turnaround Fadeaway Shot    2023
# 3          0                          Brown BLOCK (1 BLK)    2023
# 4          0                 Tucker REBOUND (Off:1 Def:0)    2023
# ...      ...                                          ...     ...
# 646362     0                     McLaughlin STEAL (1 STL)    2023
# 646363     0           Knight Traveling Turnover (P2.T16)    2023
# 646364     1  Dieng 1' Driving Layup (4 PTS) (Mann 1 AST)    2023
# 646365     0     TIMBERWOLVES Turnover: Shot Clock (T#17)    2023
# 646366     0             End of 4th Period (12:11 AM EST)    2023
#
# [646367 rows x 16 columns]

# %% [markdown]
# ## Data Setup
#
# We filter to a single player's shot attempts and convert outcomes into a binary variable:
# - 1 = made shot
# - 0 = missed shot

# %%
# Binary shot outcome
df["made"] = (df["result"] == "Made").astype(int)

# Convert clock to seconds remaining
clock_parts = df["clock"].str.extract(r"PT(\d+)M([\d\.]+)S")
df["clock_sec"] = clock_parts[0].astype(float) * 60 + clock_parts[1].astype(float)

# Sort within each game
df = df.sort_values(
    ["gameid", "period", "clock_sec"],
    ascending=[True, True, False]
).reset_index(drop=True)

df.head()
# Out:
#      gameid  period        clock  h_pts  a_pts team  playerid    player  \
# 0  22200002       1  PT07M27.00S    NaN    NaN  GSW    201939  S. Curry
# 1  22200002       1  PT07M22.00S   11.0    6.0  GSW    201939  S. Curry
# 2  22200002       1  PT07M11.00S    NaN    NaN  GSW    201939  S. Curry
# 3  22200002       1  PT05M16.00S    NaN    NaN  GSW    201939  S. Curry
# 4  22200002       1  PT03M52.00S    NaN    NaN  GSW    201939  S. Curry
#
#           type              subtype  result    x    y  dist  \
# 0  Missed Shot   Driving Layup Shot  Missed   60   10     6
# 1    Made Shot   Fadeaway Jump Shot    Made  150   79    17
# 2  Missed Shot     Pullup Jump shot  Missed    7  273    27
# 3  Missed Shot  Step Back Jump shot  Missed -151  197    25
# 4  Missed Shot            Jump Shot  Missed  -81  229    24
#
#                                      desc  season  made  clock_sec
# 0             MISS Curry 6' Driving Layup    2023     0      447.0
# 1       Curry 17' Fadeaway Jumper (4 PTS)    2023     1      442.0
# 2     MISS Curry 27' 3PT Pullup Jump Shot    2023     0      431.0
# 3  MISS Curry 25' 3PT Step Back Jump Shot    2023     0      316.0
# 4            MISS Curry 24' 3PT Jump Shot    2023     0      232.0

# %%
plt.figure(figsize=(12, 3))
plt.plot(df["made"].values[:20], marker='o', linestyle='-')
plt.title("Shot Outcomes Over Time (First 20 Shots)")
plt.xlabel("Shot Index")
plt.ylabel("Made (1) / Miss (0)")
plt.show()

# %%
df["rolling_fg"] = df["made"].rolling(window=20).mean()

plt.figure(figsize=(10, 4))
plt.plot(df["rolling_fg"])
plt.title("Rolling Field Goal Percentage (Window = 20)")
plt.xlabel("Shot Index")
plt.ylabel("FG%")
plt.show()

# %% [markdown]
# ## Basic Summary
#
# The mean represents shooting percentage.
#
# If shots are independent, we should not see strong dependence across time.

# %%
print("Mean:", df["made"].mean())
print("Variance:", df["made"].var())
# Out:
# Mean: 0.48753462603878117
# Variance: 0.25001775694296885

# %% [markdown]
# ## Feature Engineering
#
# We create lag variables to capture previous shot outcomes within each game.
#
# These will be used to test whether recent shots influence future performance.

# %%
# Create lagged shot outcomes within each game
for lag in range(1, 4):
    df[f"lag{lag}"] = df.groupby("gameid")["made"].shift(lag)

# Drop rows where lags are missing
model_df = df.dropna(subset=["lag1", "lag2", "lag3"]).copy()

# Convert to int
for lag in range(1, 4):
    model_df[f"lag{lag}"] = model_df[f"lag{lag}"].astype(int)

print("Modeling rows:", len(model_df))
model_df[["gameid", "made", "lag1", "lag2", "lag3"]].head()
# Out:
# Modeling rows: 1237
#      gameid  made  lag1  lag2  lag3
# 3  22200002     0     0     1     0
# 4  22200002     0     0     0     1
# 5  22200002     0     0     0     0
# 6  22200002     0     0     0     0
# 7  22200002     0     0     0     0

# %%
# Conditional probabilities
hot_hand_table = pd.crosstab(model_df["lag1"], model_df["made"], normalize="index")
print(hot_hand_table)

# Plot
probs = hot_hand_table[1]

plt.figure(figsize=(6, 4))
probs.plot(kind="bar")
plt.xticks([0, 1], ["Prev Miss", "Prev Make"], rotation=0)
plt.ylabel("P(Make)")
plt.title("Curry Conditional Make Probability")
plt.show()
# Out:
# made         0         1
# lag1
# 0     0.500000  0.500000
# 1     0.533662  0.466338

# %% [markdown]
# While the ACF analysis suggests little linear dependence in shot outcomes, it may fail to detect subtle probabilistic effects due to the binary nature of the data.
#
# To more directly test for a hot hand effect, we estimate a logistic autoregressive model, where the probability of making a shot depends on recent shot outcomes within the same game.

# %% [markdown]
# ## Logistic Autoregressive Model
#
# We model the probability of making a shot as a function of recent shot history.
#
# This allows us to directly test for a hot hand effect.

# %%
# Logistic autoregressive model
logit_model = smf.glm(
    formula="made ~ lag1 + lag2 + lag3",
    data=model_df,
    family=sm.families.Binomial()
).fit(cov_type="cluster", cov_kwds={"groups": model_df["gameid"]})

print(logit_model.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   made   No. Observations:                 1237
# Model:                            GLM   Df Residuals:                     1233
# Model Family:                Binomial   Df Model:                            3
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -854.23
# Date:                Wed, 08 Apr 2026   Deviance:                       1708.5
# Time:                        17:31:17   Pearson chi2:                 1.24e+03
# No. Iterations:                     4   Pseudo R-squ. (CS):           0.004062
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0945      0.118      0.804      0.421      -0.136       0.325
# lag1          -0.1326      0.120     -1.106      0.269      -0.367       0.102
# lag2           0.0238      0.127      0.187      0.852      -0.226       0.274
# lag3          -0.2150      0.124     -1.735      0.083      -0.458       0.028
# ==============================================================================

# %% [markdown]
# ## Interpretation
#
# - lag1: effect of previous shot
# - lag2, lag3: longer memory effects
#
# If coefficients are:
# - Positive = hot hand
# - Near zero = independence
# - Negative = regression to the mean
#
# In this case:
# - lag1 is slightly negative and not significant
# - lag2 is near zero
# - lag3 is slightly negative
#
# This suggests little to no evidence of a hot hand effect.

# %%
# Predictions
model_df["pred_prob"] = logit_model.predict(model_df)

model_df[["made", "lag1", "lag2", "lag3", "pred_prob"]].head()
# Out:
#    made  lag1  lag2  lag3  pred_prob
# 3     0     0     1     0   0.529552
# 4     0     0     0     1   0.469917
# 5     0     0     0     0   0.523607
# 6     0     0     0     0   0.523607
# 7     0     0     0     0   0.523607

# %%
plt.figure(figsize=(10, 4))
plt.plot(model_df["pred_prob"].values[:200], label="Predicted Prob")
plt.plot(model_df["made"].values[:200], alpha=0.5, label="Actual Outcome")
plt.legend()
plt.title("Predicted Probability vs Actual Outcomes")
plt.show()

# %% [markdown]
# ## Autocorrelation (ACF)
#
# We test whether shot outcomes are linearly dependent on previous shots.
#
# If a hot hand exists, we expect positive autocorrelation at small lags.

# %%
# ACF of shot outcomes (all games, ordered correctly)
series = model_df["made"]

plt.figure(figsize=(8, 4))
plot_acf(df["made"])
plt.title("ACF of Shot Outcomes (Stephen Curry)")
plt.xlabel("Lag")
plt.ylabel("Autocorrelation")
plt.show()

# %% [markdown]
# ACF may fail to detect dependence because the data is binary.
#
# We therefore use a logistic autoregressive model next.

# %% [markdown]
# ## Partial Autocorrelation (PACF)
#
# PACF helps isolate the direct effect of each lag.

# %%
plt.figure(figsize=(8, 4))
plot_pacf(df["made"])
plt.title("PACF of Shot Outcomes (Stephen Curry)")
plt.xlabel("Lag")
plt.ylabel("Partial Autocorrelation")
plt.show()

# %%
# Convert to class predictions
model_df["pred_class"] = (model_df["pred_prob"] >= 0.5).astype(int)

# Metrics
auc = roc_auc_score(model_df["made"], model_df["pred_prob"])
ll = log_loss(model_df["made"], model_df["pred_prob"])
acc = accuracy_score(model_df["made"], model_df["pred_class"])

print(f"ROC-AUC: {auc:.4f}")
print(f"Log Loss: {ll:.4f}")
print(f"Accuracy: {acc:.4f}")
# Out:
# ROC-AUC: 0.5361
# Log Loss: 0.6906
# Accuracy: 0.5247

# %%
print("Lag 1 correlation:", np.corrcoef(df["made"][:-1], df["made"][1:])[0,1])
# Out:
# Lag 1 correlation: -0.019344992111349

# %%
# plot diagnostics (residuals) ?
# mean absolute error (mae) ?
# root mean squared error (rmse) ?
